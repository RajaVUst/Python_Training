# %%
#Exercise 1: Shopping List Manager

cart = ["apple", "banana", "milk"]
cart.append("bread")
cart.append("eggs")
cart.remove("banana")
print("Original list:", cart)
print("Sorted list:", sorted(cart))
# Out:
# Original list: ['apple', 'milk', 'bread', 'eggs']
# Sorted list: ['apple', 'bread', 'eggs', 'milk']

# %%
#Exercise 2: Rotate the Queue

queue = ["Amit", "Reni", "Tara", "Sam"]
print("Before:", queue)
first_person = queue.pop(0)
queue.append(first_person)
print("After:", queue)
# Out:
# Before: ['Amit', 'Reni', 'Tara', 'Sam']
# After: ['Reni', 'Tara', 'Sam', 'Amit']

# %%
#Exercise 3: Running Total With Slicing

readings = [12, 15, 9, 22, 30, 4, 18]
print("First three:", readings[:3])
print("Last two:", readings[-2:])
print("Every second reading:", readings[::2])
# Out:
# First three: [12, 15, 9]
# Last two: [4, 18]
# Every second reading: [12, 9, 30, 18]

# %%
#Exercise 4: Copy vs Reference

original = [1, 2, 3]
alias = original
safe_copy = original.copy()
alias.append(100)
safe_copy.append(200)
print("Original:", original)
print("Alias:", alias)
print("Safe copy:", safe_copy)
# Out:
# Original: [1, 2, 3, 100]
# Alias: [1, 2, 3, 100]
# Safe copy: [1, 2, 3, 200]

# %%
#Exercise 5: Coordinates

location = (12.97, 77.59)
print("Location:", location)
location[0] = 13.00
# Out:
# Location: (12.97, 77.59)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 location = (12.97, 77.59)
#       4 print("Location:", location)
# ----> 5 location[0] = 13.00
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Exercise 6: Unpacking a Tuple

record = ("Reni", 91, "Cohort 2")
name, score, cohort = record
print(f"{name} scored {score} and belongs to {cohort}.")
# Out:
# Reni scored 91 and belongs to Cohort 2.

# %%
#Exercise 7: Multiple Return Values

def stats(numbers):
    low = min(numbers)
    high = max(numbers)
    avg = sum(numbers) / len(numbers)

    return low, high, avg
numbers = [4, 9, 1, 7, 15]
minimum, maximum, average = stats(numbers)
print("Minimum:", minimum)
print("Maximum:", maximum)
print("Average:", average)
# Out:
# Minimum: 1
# Maximum: 15
# Average: 7.2

# %%
#Exercise 8: De-duplicating Attendance

attendance = ["amit", "reni", "amit", "tara", "reni", "sam"]
unique_attendees = set(attendance)
print("Unique attendees:", unique_attendees)
print("Number of unique attendees:", len(unique_attendees))
# Out:
# Unique attendees: {'amit', 'reni', 'sam', 'tara'}
# Number of unique attendees: 4

# %%
#Exercise 9: Common Interests

cohort_a = {"python", "sql", "excel"}
cohort_b = {"python", "tableau", "excel"}
print("Common skills:", cohort_a & cohort_b)
print("Only in Cohort A:", cohort_a - cohort_b)
print("All skills:", cohort_a | cohort_b)
# Out:
# Common skills: {'excel', 'python'}
# Only in Cohort A: {'sql'}
# All skills: {'excel', 'python', 'tableau', 'sql'}

# %%
#Exercise 10: Fast Membership Check

seen = set(range(1000))
if 999 in seen:
    print("999 is present in the set.")
else:
    print("999 is not present in the set.")
# Out:
# 999 is present in the set.

# %%
#Exercise 11: Contact Card

contact = {
    "name": "Manikanta",
    "email": "mani@example.com",
    "phone": "9876543210"
}
print("Name:", contact["name"])
print("Email:", contact["email"])
print("Phone:", contact["phone"])
contact["city"] = "Chennai"
contact["phone"] = "9999999999"
contact.pop("email")
print("Updated contact:", contact)
# Out:
# Name: Manikanta
# Email: mani@example.com
# Phone: 9876543210
# Updated contact: {'name': 'Manikanta', 'phone': '9999999999', 'city': 'Chennai'}

# %%
#Exercise 12: Word Frequency Counter

text = "the quick brown fox jumps over the lazy dog the fox runs"
word_counts = {}
for word in text.split():
    word_counts[word] = word_counts.get(word, 0) + 1
print(word_counts)
# Out:
# {'the': 3, 'quick': 1, 'brown': 1, 'fox': 2, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1, 'runs': 1}

# %%
#Exercise 13: Class Roster

roster = [
    {"name": "Amit", "scores": [80, 90, 85]},
    {"name": "Reni", "scores": [95, 88, 92]},
    {"name": "Tara", "scores": [70, 75, 80]}
]
for student in roster:
    average = sum(student["scores"]) / len(student["scores"])
    print(
        student["name"],
        "average:",
        round(average, 1)
    )
# Out:
# Amit average: 85.0
# Reni average: 91.7
# Tara average: 75.0

# %%
#Exercise 14: Lookup Table

grade_lookup = {
    "A": 90,
    "B": 80,
    "C": 70,
    "D": 60,
    "F": 0
}
score = 84
for grade, threshold in grade_lookup.items():
    if score >= threshold:
        print("Grade:", grade)
        break
# Out:
# Grade: B

# %%
#Exercise 15: Squares and Cubes

cubes = [n ** 3 for n in range(1, 11)]
even_cubes = [n ** 3 for n in range(1, 11) if n % 2 == 0]
print("Cubes:", cubes)
print("Even cubes:", even_cubes)
# Out:
# Cubes: [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# Even cubes: [8, 64, 216, 512, 1000]

# %%
#Exercise 16: Label the Temperatures

temps = [15, 22, 31, 8, 27, 19]
labels = [
    "hot" if t >= 25 else ("mild" if t >= 15 else "cold")
    for t in temps
]
print(labels)
# Out:
# ['mild', 'mild', 'hot', 'cold', 'hot', 'mild']

# %%
#Exercise 17: Dictionary From Two Lists

names = ["Amit", "Reni", "Tara"]
scores = [78, 91, 65]
scores_dict = {
    name: score
    for name, score in zip(names, scores)
}
print(scores_dict)
# Out:
# {'Amit': 78, 'Reni': 91, 'Tara': 65}

# %%
#Exercise 18: Filtering With a Dict Comprehension

names = ["Amit", "Reni", "Tara"]
scores = [78, 91, 65]
scores_dict = {
    name: score
    for name, score in zip(names, scores)
}
passed_students = {
    name: score
    for name, score in scores_dict.items()
    if score >= 70
}
print("All students:", scores_dict)
print("70 or above:", passed_students)
# Out:
# All students: {'Amit': 78, 'Reni': 91, 'Tara': 65}
# 70 or above: {'Amit': 78, 'Reni': 91}

# %%
#Exercise 19: Vowel Counter by Word

def vowel_counts(sentence):
    result = {}
    for word in sentence.lower().split():
        count = 0
        for char in word:
            if char in "aeiou":
                count += 1
        result[word] = count
    return result
sentence = "The Quick Brown Fox Jumps"
print(vowel_counts(sentence))
# Out:
# {'the': 1, 'quick': 2, 'brown': 1, 'fox': 1, 'jumps': 1}

# %%
#Exercise 20: Grade Book Summary

def grade_summary(roster):
    result = []
    for student in roster:
        average = sum(student["scores"]) / len(student["scores"])
        if average >= 90:
            grade = "A"
        elif average >= 80:
            grade = "B"
        elif average >= 70:
            grade = "C"
        elif average >= 60:
            grade = "D"
        else:
            grade = "F"
        result.append({
            "name": student["name"],
            "average": round(average, 1),
            "grade": grade
        })
    return result
roster = [
    {"name": "Amit", "scores": [80, 90, 85]},
    {"name": "Reni", "scores": [95, 88, 92]},
    {"name": "Tara", "scores": [70, 75, 80]}
]
summary = grade_summary(roster)
print(summary)
# Out:
# [{'name': 'Amit', 'average': 85.0, 'grade': 'B'}, {'name': 'Reni', 'average': 91.7, 'grade': 'A'}, {'name': 'Tara', 'average': 75.0, 'grade': 'C'}]

# %%
#Exercise 21: Unique Word Finder

def unique_words(text):
    words = text.lower().split()
    unique = set(words)
    return sorted(unique)
text = "Python is easy and Python is powerful"
print(unique_words(text))
# Out:
# ['and', 'easy', 'is', 'powerful', 'python']

# %%
#Exercise 22: FizzBuzz Structured

def fizzbuzz_map(n):
    result = {}
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            value = "FizzBuzz"
        elif i % 3 == 0:
            value = "Fizz"
        elif i % 5 == 0:
            value = "Buzz"
        else:
            value = str(i)
        result[i] = value
    return result
print(fizzbuzz_map(20))
# Out:
# {1: '1', 2: '2', 3: 'Fizz', 4: '4', 5: 'Buzz', 6: 'Fizz', 7: '7', 8: '8', 9: 'Fizz', 10: 'Buzz', 11: '11', 12: 'Fizz', 13: '13', 14: '14', 15: 'FizzBuzz', 16: '16', 17: '17', 18: 'Fizz', 19: '19', 20: 'Buzz'}

# %%
#Exercise 23: Password Strength Report

def password_report(passwords):
    result = {
        "weak": [],
        "medium": [],
        "strong": []
    }
    for password in passwords:
        has_digit = any(ch.isdigit() for ch in password)

        if len(password) >= 10 and has_digit:
            result["strong"].append(password)

        elif len(password) >= 6:
            result["medium"].append(password)

        else:
            result["weak"].append(password)
    return result
passwords = [
    "abc",
    "hello1",
    "python",
    "welcome123",
    "abcdef1234",
    "hi"
]
print(password_report(passwords))
# Out:
# {'weak': ['abc', 'hi'], 'medium': ['hello1', 'python'], 'strong': ['welcome123', 'abcdef1234']}
