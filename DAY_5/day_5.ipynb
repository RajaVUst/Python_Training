# %%
#1
groc=["sugar","mlk","curd"]
groc.append("oil")
groc.append("chilly")
groc.remove("oil")
#groc.sort()
print(f" UN Sorted grocires list:{groc}")
print(f"Sorted grocires list:{sorted(groc)}")
# Out:
#  UN Sorted grocires list:['sugar', 'mlk', 'curd', 'chilly']
# Sorted grocires list:['chilly', 'curd', 'mlk', 'sugar']

# %%
#2
data= ["Amit", "Reni", "Tara", "Sam"]
print("Before",data)
data.pop(0)

data.append("Amit")
print("After",data)
# Out:
# Before ['Amit', 'Reni', 'Tara', 'Sam']
# After ['Reni', 'Tara', 'Sam', 'Amit']

# %%
#3
readings = [12, 15, 9, 22, 30, 4, 18]
print(f"first three readings{readings[:3]}")
print(f"Last two  readings{readings[-2:]}")
print(f"Every second readings{readings[::2]}")
# Out:
# first three readings[12, 15, 9]
# Last two  readings[4, 18]
# Every second readings[12, 9, 30, 18]

# %%
#4
original=[1,2,3]
alias=original
safe_copy=original.copy()
alias.append(100)
safe_copy.append(200)
print("Alias:",alias)
print("Copy:",safe_copy)
print("Original:",original)
print("alias and original point to the same list, so original also gets 100, but safe_copy is a separate list.")
# Out:
# Alias: [1, 2, 3, 100]
# Copy: [1, 2, 3, 200]
# Original: [1, 2, 3, 100]
# alias and original point to the same list, so original also gets 100, but safe_copy is a separate list.

# %%
#5
location = (12.97, 77.59) 
location[0]=12.00
print(location)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #5
#       2 location = (12.97, 77.59)
# ----> 3 location[0]=12.00
#       4 print(location)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#6
record = ("Reni", 91, "Cohort 2")
name, score, cohort= record
print(f"Name:{name}, Score:{score}, Cohort:{cohort}")
# Out:
# Name:Reni, Score:91, Cohort:Cohort 2

# %%
#7
def stat(numbers):
    average=sum(numbers)/len(numbers)
    return min(numbers), max(numbers), average
    
record=tuple(map(int,input("enter the values:").split()))
min_value,max_value,avg=stat(record)
print(f"Minimum value:{min_value}")
print(f"Maximum value:{max_value}")
print(f"Average :{avg}")
# Out:
# enter the values: 12 3 4 5 56 4
# Minimum value:3
# Maximum value:56
# Average :14.0

# %%
#8
attendence=["amit", "reni", "amit", "tara", "reni", "sam"]
att=set(attendence)
coun_att=len(att)
print(f"count of attendes before removing dupicates:{attendence} is {len(attendence)}")
print(f"count of attendes after removing duplicates:{att} is {coun_att}")
# Out:
# count of attendes before removing dupicates:['amit', 'reni', 'amit', 'tara', 'reni', 'sam'] is 6
# count of attendes after removing duplicates:{'sam', 'reni', 'amit', 'tara'} is 4

# %%
#9
cohort_a = {"python", "sql", "excel"}  
cohort_b = {"python", "tableau", "excel"}
print(f"Skills common to both cohorts:{cohort_a & cohort_b}")
print(f"the skills unique to cohort_a:{cohort_a - cohort_b}")
print(f" ALL Skills from  both cohorts:{cohort_a | cohort_b}")
# Out:
# Skills common to both cohorts:{'python', 'excel'}
# the skills unique to cohort_a:{'sql'}
#  ALL Skills from  both cohorts:{'sql', 'python', 'tableau', 'excel'}

# %%
#10
seen=set(range(1000))
if 999 in seen:
    print("999 is presen in the seen ")
else:
    print("999 is not present in seen")   
## A set is better than a list because membership checks are much faster for large collections.
# Out:
# 999 is presen in the seen

# %%
#11
data={'name':"surenda",'email':"sure@gamil.com", 'phone':61263453416}
print(data)
data['city']="hyd"
data['phone']=7643763673473463
print(data)
data.pop('email')
print(data)
# Out:
# {'name': 'surenda', 'email': 'sure@gamil.com', 'phone': 61263453416}
# {'name': 'surenda', 'email': 'sure@gamil.com', 'phone': 7643763673473463, 'city': 'hyd'}
# {'name': 'surenda', 'phone': 7643763673473463, 'city': 'hyd'}

# %%
#12
text = "the quick brown fox jumps over the lazy dog the fox runs"
text=text.split()
word_count={}
for word in text:
    
    word_count[word]=word_count.get(word,0)+1
print(word_count)
# Out:
# {'the': 3, 'quick': 1, 'brown': 1, 'fox': 2, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1, 'runs': 1}

# %%
 #13
records=[
    {'name':"Surendr",'score':[56,67,90]},
    {'name':"ram",'score':[54,57,50]},
    {'name':"nag",'score':[56,57,90]}
 ]

for student in records:
    average=sum(student['score'])/len(student['score'])
    print(f"{student['name']}->{average:.1f}")
# Out:
# Surendr->71.0
# ram->53.7
# nag->67.7

# %%
#14
grade_lookup={
    "A":90,
    "B":80,
    "C":70,
    "D":60,
    "F":0

}
score=int(input("ENter the score:"))
for grade, minimum in grade_lookup.items():
    if score>=minimum:
        print("Grade:",grade)
        break
# Out:
# ENter the score: 99
# Grade: A

# %%
#15
n=int(input("Enter the number:"))
result=[i**3 for i in range(1,n+1)]
print(f"Cubes from 1 to 10:{result}")
result=[i**3 for i in range(1,n+1) if i%2==0]
print(f"Even cubes from 1 to 10:{result}")
# Out:
# Enter the number: 10
# Cubes from 1 to 10:[1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# Even cubes from 1 to 10:[8, 64, 216, 512, 1000]

# %%
#16
temperature= [15, 22, 31, 8, 27, 19]
result=[f"{temp}-> {"hot" if temp>=25 else ("mild" if temp>=15 else "cold")}" for temp in temperature]
print(result)
# Out:
# ['15-> mild', '22-> mild', '31-> hot', '8-> cold', '27-> hot', '19-> mild']

# %%
#17
names = ["Amit", "Reni", "Tara"]
scores = [78, 91, 65]
result={ name:score for name,score in zip(names,scores)}
print(result)
# Out:
# {'Amit': 78, 'Reni': 91, 'Tara': 65}

# %%
#18
score_dict={name:score for name,score in zip(names,scores)}
result={name:score for name ,score in score_dict.items()if score>=70}
print(result)
# Out:
# {'Amit': 78, 'Reni': 91}

# %%
#19
def vowel_count(senetence):
    words=senetence.split()
    return {
      word:sum  (1 for ch in word.lower() if ch in 'aeiou') for word in words
    }
senetence=input("Enter the sentence:")
print(vowel_count(senetence))
# Out:
# Enter the sentence: The Quick Brown Fox Jumps
# {'The': 1, 'Quick': 2, 'Brown': 1, 'Fox': 1, 'Jumps': 1}

# %%
def grade_summary(roster):
    result=[]
    for student in roster:
        average=sum(student["scores"])/len(student["scores"])
        if average>=90:
            grade="A"
        elif average>=80:
            grade="B"
        elif average>=70:
            grade="C"
        elif average>=60:
            grade="D"
        else:
            grade="F"
        result.append({"name":student['name'],
        "average:":f"{average:.2f}",
        "Grade":grade})
    return result             


roster=[
    {'name':"surendra",'scores':[56,76,98]},
    {'name':"prem",'scores':[87,98,65]},
    {'name':"ram",'scores':[98,65,43]},
]        

print(grade_summary(roster))
# Out:
# [{'name': 'surendra', 'average:': '76.67', 'Grade': 'C'}, {'name': 'prem', 'average:': '83.33', 'Grade': 'B'}, {'name': 'ram', 'average:': '68.67', 'Grade': 'D'}]

# %%
#21
def unique_words(text):
    senetence=text.lower().split()
    result=set(senetence)
    return sorted(result)
text=input("Enter the text:")
print(unique_words(text))
# Out:
# Enter the text: hi my name is surendar and am from am from hyd
# ['am', 'and', 'from', 'hi', 'hyd', 'is', 'my', 'name', 'surendar']

# %%
def fizzbuzz_map(n):
    result={}
    for i in range(1, n+1):
        if i%3==0 and i%5==0:
            result[i]="FizzBuzz"
        elif i%3==0:
            result[i]="Fizz"
        elif i%5==0:
            result[i]="Buzz"
        else:
            result[i]=str(i)
    return result                

n=int(input("ENtehr the number"))    
print(fizzbuzz_map(n))
# Out:
# ENtehr the number 20
# {1: '1', 2: '2', 3: 'Fizz', 4: '4', 5: 'Buzz', 6: 'Fizz', 7: '7', 8: '8', 9: 'Fizz', 10: 'Buzz', 11: '11', 12: 'Fizz', 13: '13', 14: '14', 15: 'FizzBuzz', 16: '16', 17: '17', 18: 'Fizz', 19: '19', 20: 'Buzz'}

# %%
def password_report(passwords):
    result = {
        "weak": [],
        "medium": [],
        "strong": []
    }

    for pw in passwords:
        if len(pw) < 6:
            result["weak"].append(pw)

        elif len(pw) >= 10 and any(ch.isdigit() for ch in pw):
            result["strong"].append(pw)

        else:
            result["medium"].append(pw)

    return result


passwords = [
    "abc",
    "hello",
    "python",
    "python123",
    "MyPassword1",
    "abcdef123456"
]

print(password_report(passwords))
# Out:
# {'weak': ['abc', 'hello'], 'medium': ['python', 'python123'], 'strong': ['MyPassword1', 'abcdef123456']}
