# %%
# PART A - lISTS

# %%
# exercise 1

cart = ["Apple", "Milk", "Bread"]
cart.append("Eggs")
cart.append("Rice")
cart.remove("Milk")

print(sorted(cart))
# Out:
# ['Apple', 'Bread', 'Eggs', 'Rice']

# %%
# exercise 2

queue = ["Chaila", "Shree", "Lekhya", "Asmitha"]
print("Before:", queue)
first_person = queue.pop(0)
queue.append(first_person)

print("After:", queue)
# Out:
# Before: ['Chaila', 'Shree', 'Lekhya', 'Asmitha']
# After: ['Shree', 'Lekhya', 'Asmitha', 'Chaila']

# %%
# exercise 3

readings = [12, 15, 9, 22, 30, 4, 18]

print("First three:", readings[:3])
print("Last two:", readings[-2:])
print("Every second reading:", readings[::2])
# Out:
# First three: [12, 15, 9]
# Last two: [4, 18]
# Every second reading: [12, 9, 30, 18]

# %%
# exercise 4

original = [1, 2, 3]
alias = original
safe_copy = original.copy()
alias.append(100)
safe_copy.append(200)

print("Original:", original)
print("Alias:", alias)
print("Safe copy:", safe_copy)
# Out:
# Original: [1, 2, 3, 100]
# Alias: [1, 2, 3, 100]
# Safe copy: [1, 2, 3, 200]

# %%
# PART B - TUPLES

# %%
# exercise 5

location = (12.97, 77.59)
location[0] = 13.00

### Tuples are immutable, meaning their values cannot be changed after creation.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # exercise 5
#       3 location = (12.97, 77.59)
# ----> 4 location[0] = 13.00
#
# TypeError: 'tuple' object does not support item assignment

# %%
# exercise 6

record = ("Chaila", 91, "Cohort 2")
name, score, cohort = record

print(f"{name} scored {score} and belongs to {cohort}.")
# Out:
# Chaila scored 91 and belongs to Cohort 2.

# %%
# exercise 7

def stats(numbers):
    low = min(numbers)
    high = max(numbers)
    avg = sum(numbers) / len(numbers)
    return low, high, avg
minimum, maximum, average = stats([4, 9, 1, 7, 15])

print(f"Minimum: {minimum}")
print(f"Maximum: {maximum}")
print(f"Average: {average}")
# Out:
# Minimum: 1
# Maximum: 15
# Average: 7.2

# %%
# PART C - SETS

# %%
# exercise 8

attendance = ["Chaila", "Shree", "Chaila","sam"]
unique_attendees = set(attendance)

print("Unique attendees:", unique_attendees)
print("Number of unique attendees:", len(unique_attendees))
# Out:
# Unique attendees: {'Shree', 'Chaila', 'sam'}
# Number of unique attendees: 3

# %%
# exercise 9

cohort_a = {"python", "sql", "excel"}
cohort_b = {"python", "tableau", "excel"}

print("Common skills:", cohort_a & cohort_b)
print("Skills unique to Cohort A:", cohort_a - cohort_b)
print("All skills:", cohort_a | cohort_b)
# Out:
# Common skills: {'python', 'excel'}
# Skills unique to Cohort A: {'sql'}
# All skills: {'python', 'sql', 'excel', 'tableau'}

# %%
# exercise 10

seen = set(range(1000))
if 999 in seen:
    print("999 is present in the set.")
else:
    print("999 is not present in the set.")
# Out:
# 999 is present in the set.

# %%
# PART D - DICTIONARIES 7 NESTED STRUCTURES

# %%
# exercise 11

contact = {
    "name": "Chaila",
    "email": "chailashree@example.com",
    "phone": "8189945362"
}

print("Name:", contact["name"])
print("Email:", contact["email"])
print("Phone:", contact["phone"])

# Add a new key
contact["city"] = "Coimbatore"

# Update the phone number
contact["phone"] = "9080424881"

# Remove the email key
contact.pop("email")

print("Updated contact:", contact)
# Out:
# Name: Chaila
# Email: chailashree@example.com
# Phone: 8189945362
# Updated contact: {'name': 'Chaila', 'phone': '9080424881', 'city': 'Coimbatore'}

# %%
# exercise 12 

text = "the quick brown fox jumps over the lazy dog the fox runs"
words = text.split()
word_counts = {}
for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

print(word_counts)
# Out:
# {'the': 3, 'quick': 1, 'brown': 1, 'fox': 2, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1, 'runs': 1}

# %%
# exercise 13

roster = [
    {
        "name": "Chaila",
        "scores": [85, 90, 95]
    },
    {
        "name": "Shree",
        "scores": [78, 82, 88]
    },
    {
        "name": "Dhilip",
        "scores": [92, 89, 96]
    }
]

for student in roster:
    average = sum(student["scores"]) / len(student["scores"])
    print(f"{student['name']}: {round(average, 1)}")
# Out:
# Chaila: 90.0
# Shree: 82.7
# Dhilip: 92.3

# %%
# exercise 14 

grade_lookup = {
    "A": 90,
    "B": 80,
    "C": 70,
    "D": 60,
    "F": 0
}
score = 84
for grade, threshold in grade_lookup.items():
    if score >= threshold:
        print(f"Score: {score} | Grade: {grade}")
        break
# Out:
# Score: 84 | Grade: B

# %%
# PART E - COMPREHENSIONS

# %%
# exercise 15 

cubes = [n ** 3 for n in range(1, 11)]
even_cubes = [n ** 3 for n in range(1, 11) if n % 2 == 0]

print("Cubes:", cubes)
print("Even cubes:", even_cubes)
# Out:
# Cubes: [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# Even cubes: [8, 64, 216, 512, 1000]

# %%
# exercise 16

temps = [15, 22, 31, 8, 27, 19]
labels = [
    "hot" if t >= 25 else ("mild" if t >= 15 else "cold")
    for t in temps
]
print(labels)
# Out:
# ['mild', 'mild', 'hot', 'cold', 'hot', 'mild']

# %%
# exercise 17

names = ["Chaila", "Shree", "Dhilip"]
scores = [78, 91, 65]
scores_dict = {
    name: score
    for name, score in zip(names, scores)
}
print(scores_dict)
# Out:
# {'Chaila': 78, 'Shree': 91, 'Dhilip': 65}

# %%
# exercise 18

scores_dict = {
    "Chaila": 78,
    "Shree": 91,
    "Dhilip": 65
}
passing_scores = {
    name: score
    for name, score in scores_dict.items()
    if score >= 70
}

print(passing_scores)
# Out:
# {'Chaila': 78, 'Shree': 91}

# %%
# PART F - CUMULATIVE CHALLENGES

# %%
# exercise 19

def vowel_counts(sentence):
    words = sentence.lower().split()
    result = {}
    for word in words:
        count = 0
        for char in word:
            if char in "aeiou":
                count += 1
        result[word] = count
    return result
sentence = "The Quick Brown Fox Jumps"

print(vowel_counts(sentence))
# Out:
# {'the': 1, 'quick': 2, 'brown': 1, 'fox': 1, 'jumps': 1}

# %%
# exercise 20

def grade_summary(roster):
    result = []
    for student in roster:
        average = sum(student["scores"]) / len(student["scores"])
        if average >= 90:
            grade = "A"
        elif average >= 80:
            grade = "B"
        elif average >= 70:
            grade = "C"
        elif average >= 60:
            grade = "D"
        else:
            grade = "F"
        result.append({
            "name": student["name"],
            "average": round(average, 1),
            "grade": grade
        })
    return result
roster = [
    {"name": "Chaila", "scores": [78, 85, 80]},
    {"name": "Shree", "scores": [91, 95, 89]},
    {"name": "Dhilip", "scores": [65, 70, 68]}
]

print(grade_summary(roster))
# Out:
# [{'name': 'Chaila', 'average': 81.0, 'grade': 'B'}, {'name': 'Shree', 'average': 91.7, 'grade': 'A'}, {'name': 'Dhilip', 'average': 67.7, 'grade': 'D'}]

# %%
# exercise 21 

def unique_words(text):
    words = text.lower().split()
    unique = set(words)
    return sorted(unique)
text = "Python is easy and Python is powerful"

print(unique_words(text))
# Out:
# ['and', 'easy', 'is', 'powerful', 'python']

# %%
# exercise 22

def fizzbuzz_map(n):
    result = {}
    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            result[i] = "FizzBuzz"
        elif i % 3 == 0:
            result[i] = "Fizz"
        elif i % 5 == 0:
            result[i] = "Buzz"
        else:
            result[i] = str(i)
    return result

print(fizzbuzz_map(20))
# Out:
# {1: '1', 2: '2', 3: 'Fizz', 4: '4', 5: 'Buzz', 6: 'Fizz', 7: '7', 8: '8', 9: 'Fizz', 10: 'Buzz', 11: '11', 12: 'Fizz', 13: '13', 14: '14', 15: 'FizzBuzz', 16: '16', 17: '17', 18: 'Fizz', 19: '19', 20: 'Buzz'}

# %%
# exercise 23

def password_report(passwords):
    result = {
        "weak": [],
        "medium": [],
        "strong": []
    }
    for pw in passwords:
        has_digit = any(ch.isdigit() for ch in pw)
        
        if len(pw) >= 10 and has_digit:
            result["strong"].append(pw)
        elif len(pw) >= 6:
            result["medium"].append(pw)
        else:
            result["weak"].append(pw)
    return result
    
passwords = [
    "abc",
    "python",
    "hello123",
    "StrongPass1",
    "abcdefghi",
    "MyPassword99"
]

print(password_report(passwords))
# Out:
# {'weak': ['abc'], 'medium': ['python', 'hello123', 'abcdefghi'], 'strong': ['StrongPass1', 'MyPassword99']}
