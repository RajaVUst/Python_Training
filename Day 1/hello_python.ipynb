# %%
#Variable Declarations
name = 'Aditi'
age = 24
height_m = 1.65
has_coded_before = False

# %%
#Printing each Variable Type
print(type(name))
print(type(age))
print(type(height_m))
print(type(has_coded_before))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#Getting a String and Typecasting it into integer and printing the result multiplied by 2
fav_str = input('Enter your Favourite Number : ')
fav_num = int(fav_str)
print(fav_num * 2)
# Out:
# Enter your Favourite Number :  10
# 20

# %%
#Using f-string method to print multiple variable into a single line
print(f'Hi {name}, you are {age} years old and {height_m}m tall')
# Out:
# Hi Aditi, you are 24 years old and 1.65m tall
