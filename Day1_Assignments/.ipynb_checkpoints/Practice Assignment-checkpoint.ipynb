# %%
name = "Aditi"
age = 24
city = "Chennai"
is_employed = True
print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print(f"Employed: {is_employed}")
# Out:
# Name: Aditi
# Age: 24
# City: Chennai
# Employed: True

# %%
a = 10
b = 10.0
c = "10"
d = 10 == 10
e = "True"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
print(f"Division: {num1 / num2}")
# Out:
# Enter first number:  15
# Enter second number:  5
# Addition: 20.0
# Subtraction: 10.0
# Multiplication: 75.0
# Division: 3.0

# %%
n = 17
is_even = (n % 2 == 0)
print(f"{n} is {is_even}")
# Out:
# 17 is False

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = celsius * 9 / 5 + 32
print(f"Celsius: {celsius:.1f}°C | Fahrenheit: {fahrenheit:.1f}°F")
# Out:
# Enter temperature in Celsius:  38.6
# Celsius: 38.6°C | Fahrenheit: 101.5°F

# %%
total_bill = float(input("Enter the bill amount"))
people = int(input("Enter the no. of people to split"))
wants_tip = (input("do you want to add 10% tip:")=="yes")
tip = wants_tip== True and total_bill*0.1 or 0 
print((total_bill+tip)/people)
# Out:
# Enter the bill amount 100
# Enter the no. of people to split 5
# do you want to add 10% tip: no
# 20.0

# %%
a = 5
b = 10

temp = a
a = b
b = temp
print(f"a = {a}")
print(f"b = {b}")

#second way
a, b = b, a
print(f"a = {a}")
print(f"b = {b}")
# Out:
# a = 10
# b = 5
# a = 5
# b = 10

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
perimeter = 2 * (length + width)

print(f"Area: {area}")
print(f"Perimeter: {perimeter}")
# Out:
# Enter length:  15
# Enter width:  5
# Area: 75.0
# Perimeter: 40.0

# %%
print(7 // 2)

print(7 % 2)

print(2 ** 3)

print(10 > 5 and 3 > 5)


print(10 > 5 or 3 > 5)

print(not True)

print("5" + "5")
print(5 == 5.0)
# Out:
# 3
# 1
# 8
# False
# True
# False
# 55
# True

# %%
name = input("Enter name")
price = float(input("Enter the price"))
in_stock = input("Enter the stock availability ") 

stock_status = "In Stock" if in_stock else "Out of Stock"

print(f"{name} — ₹{price:.2f} ({stock_status})")
# Out:
# Enter name Notebook
# Enter the price 149.00
# Enter the stock availability  True
# Notebook — ₹149.00 (In Stock)

# %%
weight = float(input("Enter weight in kilograms: "))
height = float(input("Enter height in metres: "))
bmi = weight / (height ** 2)
print(f"BMI: {bmi:.1f}")
# Out:
# Enter weight in kilograms:  60
# Enter height in metres:  1.6
# BMI: 23.4

# %%
n = 15
div_by_3 = (n % 3 == 0)
div_by_5 = (n % 5 == 0)
div_by_both = div_by_3 and div_by_5
print(f"Divisible by 3: {div_by_3}")
print(f"Divisible by 5: {div_by_5}")
print(f"Divisible by both: {div_by_both}")
# Out:
# Divisible by 3: True
# Divisible by 5: True
# Divisible by both: True

# %%
amount = float(input("Enter amount in USD: "))
conversion_rate = float(input("Enter USD to INR conversion rate: "))
amount_inr = amount * conversion_rate
print(f"USD: ${amount:,.2f}")
print(f"INR: ₹{amount_inr:,.2f}")
# Out:
# Enter amount in USD:  1234
# Enter USD to INR conversion rate:  54
# USD: $1,234.00
# INR: ₹66,636.00

# %%
score1 = float(input("Enter first test score: "))
score2 = float(input("Enter second test score: "))
score3 = float(input("Enter third test score: "))
average = (score1 + score2 + score3) / 3
has_passed = average >= 40
print(f"Average: {average:.1f} | Passed: {has_passed}")
# Out:
# Enter first test score:  90
# Enter second test score:  85
# Enter third test score:  89
# Average: 88.0 | Passed: True
