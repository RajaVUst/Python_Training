# %%
first_name = input("Enter first name: ")
last_name = input("Enter last name :")
print(f"Hello, {first_name} {last_name}!")
# Out:
# Enter first name:  Vinayasri
# Enter last name : Sakinala
# Hello, Vinayasri Sakinala!

# %%
code = "PYTHON2026SALE"
print(code[0:6])
print(code[-4:])
print(code[::-1])
# Out:
# PYTHON
# SALE
# ELAS6202NOHTYP

# %%
#palindrome
word = input("Enter the word")
is_palindrome = word==word[::-1]
print(is_palindrome)
# Out:
# Enter the word vinaya
# False

# %%
email = input("Enter an email : ")
username, domain = email.split('@')
print(f" username is {username}, domain is  {domain}" )
# Out:
# Enter an email :  vinaya@gmail.com
#  username is vinaya, domain is  gmail.com

# %%
title = " My First  Python Project!! "
title = title.strip()
title= title.replace("!!","")
title = title.lower()
title = title.replace(" ", "_")
print(title)
# Out:
# my_first__python_project

# %%
sen = input("Enter the string")
total_characters =  len(sen)
vowel_count= sen.count('a')+sen.count('e')+sen.count('i')+sen.count('o')+sen.count('u')
words_count = len(sen.split())
print(f"Total Characters count : {total_characters}")
print(f"Total words count: {words_count}")
print(f"Total vowels count : {vowel_count}") 
if total_characters>30:
    print("longer than 30")
# Out:
# Enter the string My name is Vinayasri
# Total Characters count : 20
# Total words count: 4
# Total vowels count : 7

# %%
full_name = input("Enter full name :")
names = full_name.split()
print(names[0][0]+names[1][0])
# Out:
# Enter full name : Vinayasri Sakinala
# VS

# %%
full="="*20
partial = "="*8 + "-"*12
print(f"Full : {full} ")
print(f"Partial : {partial} ")
# Out:
# Full : ====================
# Partial : ========------------

# %%
filename = input("Enter the filename : ")
if filename.endswith(".docx"):
    print(" Filename endswith .docx")
elif filename.endswith(".pdf"):
    print("Filename endswith .pdf")
# Out:
# Enter the filename :  day2_notes.docx
#  Filename endswith .docx

# %%
text = "the quick brown fox"
index = text.find("brown")
replaced_text = text.replace("brown", "red")
print(f"The original text : {text}")
print(f"
