# %%
# Part A

# %%
sentence = " Python IS Fun to Learn !!"

# %%
clean = sentence.strip()
print(clean)
# Out:
# Python IS Fun to Learn !!

# %%
print(clean[0])
print(clean[-1])
print(clean[:5])
# Out:
# P
# !
# Pytho

# %%
print(clean.lower())
print(clean.upper())
# Out:
# python is fun to learn !!
# PYTHON IS FUN TO LEARN !!

# %%
words = clean.split()
print(words)
print(len(words))
# Out:
# ['Python', 'IS', 'Fun', 'to', 'Learn', '!!']
# 6

# %%
print(clean.replace("Fun","Powerful"))
# Out:
# Python IS Powerful to Learn !!

# %%
print("-".join(words))
# Out:
# Python-IS-Fun-to-Learn-!!

# %%
print(f"words: {len(words)} | Reversed: {clean[::-1]}")
# Out:
# words: 6 | Reversed: !! nraeL ot nuF SI nohtyP

# %%
# Part B

# %%
#Debug 1- IndentationError
print("Start")
  print("Middle")
print("End")
# Out:
#   Cell In[13], line 3
#     print("Middle")
#     ^
# IndentationError: unexpected indent

# %%
print("Start")
print("Middle")
print("End")
# Out:
# Start
# Middle
# End

# %%
#Debug 2- TypeError
age = 24
message = "I am " + age + " years old"
print(message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 #Debug 2- TypeError
#       2 age = 24
# ----> 3 message = "I am " + age + " years old"
#       4 print(message)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 24
message = "I am " + str(age) + " years old"
print(message)
# Out:
# I am 24 years old

# %%
#Debug 3- NameError
username = "chaila_G"
print(f"Welcome, {usernam}!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 #Debug 3- NameError
#       2 username = "chaila_G"
# ----> 3 print(f"Welcome, {usernam}!")
#
# NameError: name 'usernam' is not defined

# %%
username = "chaila_G"
print(f"Welcome, {username}!")
# Out:
# Welcome, chaila_G!

# %%
#Debug 4-IndexError
word = "Python"
print(word[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 #Debug 4-IndexError
#       2 word = "Python"
# ----> 3 print(word[6])
#
# IndexError: string index out of range

# %%
word = "Python"
print(word[5])
# Out:
# n

# %%
#Debug 5- Silent Logic Bug
sentence = "one two three"
word_list = sentence.split(",")
print(f"Word count: {len(word_list)}")
# Out:
# Word count: 1

# %%
sentence = "one two three"
word_list = sentence.split()
print(f"Word count: {len(word_list)}")
# Out:
# Word count: 3

# %%
# Part C

# %%
# exercise 1 - Name Tag Formatter

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

print(f"Hello, {first_name.title()} {last_name.title()}!")
# Out:
# Enter your first name:  Chaila
# Enter your last name:  Shree
# Hello, Chaila Shree!

# %%
# exercise 2 - Coupon Code Slicer

# %%
code = "PYTHON2026SALE"

print(f"First 6 characters: {code[:6]}")
print(f"Last 4 characters: {code[-4:]}")
print(f"Reversed: {code[::-1]}")
# Out:
# First 6 characters: PYTHON
# Last 4 characters: SALE
# Reversed: ELAS6202NOHTYP

# %%
# exercise 3 - Palindrome Checker

# %%
word = "level"

is_palindrome = (word == word[::-1])

print(is_palindrome)
# Out:
# True

# %%
# exercise 4 - Email Splitter

# %%
email = "chaila.g@ust.com"

username, domain = email.split("@")

print(f"Username: {username}")
print(f"Domain: {domain}")
# Out:
# Username: chaila.g
# Domain: ust.com

# %%
# exercise 5 - Slug Normalizer

# %%
title = "  My First   Python Project!!  "

clean = title.strip()
print(clean)

clean = clean.replace("!!", "")
print(clean)

clean = clean.lower()
print(clean)

clean = clean.replace(" ", "_")
print(clean)
# Out:
# My First   Python Project!!
# My First   Python Project
# my first   python project
# my_first___python_project

# %%
# exercise 6 - Sentence Dashboard

# %%
sentence = "Python is a powerful programming language"

character_count = len(sentence)
word_count = len(sentence.split())

vowel_count = (
    sentence.count("a")
    + sentence.count("e")
    + sentence.count("i")
    + sentence.count("o")
    + sentence.count("u")
)

longer_than_30 = len(sentence) > 30

print(f"Character count: {character_count}")
print(f"Word count: {word_count}")
print(f"Vowel count: {vowel_count}")
print(f"Longer than 30 characters: {longer_than_30}")
# Out:
# Character count: 41
# Word count: 6
# Vowel count: 13
# Longer than 30 characters: True

# %%
# part D

# %%
# exercise 7 - Initials Generator

# %%
full_name = "Chaila Shree"
names = full_name.split()
initials = names[0][0] + names[1][0]
print(initials)
# Out:
# CS

# %%
# exercise 8 - Loading Bar

# %%
full_bar = "=" * 20
partial_bar = "=" * 8 + "-" * 12

print(f"Full: {full_bar}")
print(f"Partial: {partial_bar}")
# Out:
# Full: ====================
# Partial: ========------------

# %%
# exercise 9 - File Extension Checker

# %%
filename = "day2_notes.docx"

print(filename.endswith(".docx"))
print(filename.endswith(".pdf"))
# Out:
# True
# False

# %%
# exercise 10 - Find and Replace Report

# %%
text = "the quick brown fox"

index = text.find("brown")
new_text = text.replace("brown", "red")

print(f"Original: {text}")
print(f"Index of 'brown': {index}")
print(f"New text: {new_text}")
# Out:
# Original: the quick brown fox
# Index of 'brown': 10
# New text: the quick red fox

# %%
# exercise 11 - Username Validator

# %%
username = "chaila_03"

print(f"Alphanumeric: {username.isalnum()}")
print(f"Length: {len(username)}")
print(f"At least 6 characters: {len(username) >= 6}")
# Out:
# Alphanumeric: False
# Length: 9
# At least 6 characters: True

# %%
# exercise 12 - Title Case vs. Capitalize

# %%
phrase = "the quick brown fox"

print(f"Title: {phrase.title()}")
print(f"Capitalize: {phrase.capitalize()}")
# Out:
# Title: The Quick Brown Fox
# Capitalize: The quick brown fox

# %%
# exercise 13 - Receipt Line Formatter

# %%
item = "Notebook"
price = 149.0

print(f"{item:<15}|{price:>8.2f}")
# Out:
# Notebook       |  149.00

# %%
# exercise 14 - Traceback Autopsy

# %%
#Traceback (most recent call last):
# File "report.py", line 4, in <module>
#   average = total / count
# ZeroDivisionError: division by zero

# %%
# The program attempted to divide total by count, but count has a value of 0, and division by zero is not allowed in Python.
