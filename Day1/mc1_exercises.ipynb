# %%
#Exercise 1

name = "Keerthi"
age = 23
city = "Hyderabad"
is_employed = True 
print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print(f"Employed: {is_employed}")
# Out:
# Name: Keerthi
# Age: 23
# City: Hyderabad
# Employed: True

# %%
# Exercise 2
 
a = 10
b = 10.0
c = "10"
d = 10 == 10
e = "True"
 
print(type(a))  
print(type(b))  
print(type(c))  
print(type(d))  
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>

# %%
#Exercise 3
 
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
 
print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
print(f"Division: {num1 / num2}")
# Out:
# Enter first number:  3
# Enter second number:  5
# Addition: 8.0
# Subtraction: -2.0
# Multiplication: 15.0
# Division: 0.6

# %%
#Exercise 4
 
n = 17
is_even = (n % 2 == 0)
print(f"{n} is even: {is_even}")
# Out:
# 17 is even: False

# %%
#Exercise 5
 
celsius = float(input("Enter temperature in Celsius: ")) 
fahrenheit = celsius * 9 / 5 + 32 
print(f"Celsius: {celsius:.1f}°C | Fahrenheit: {fahrenheit:.1f}°F")
# Out:
# Enter temperature in Celsius:  32
# Celsius: 32.0°C | Fahrenheit: 89.6°F

# %%
#Exercise 6
 
bill = float(input("Enter total bill: "))
people = int(input("Enter number of people: ")) 
wants_tip = input("Do you want to add a 10% tip? (yes/no): ").lower() == "yes" 
if wants_tip:
    bill = bill * 1.10
share = bill / people
print(f"Each person's share: ₹{share:.2f}")
# Out:
# Enter total bill:  3200
# Enter number of people:  3
# Do you want to add a 10% tip? (yes/no):  yes
# Each person's share: ₹1173.33

# %%
#Part D
 
#Exercise 7
 
a = 5
b = 10 
temp = a
a = b
b = temp 
print(f"a = {a}")
print(f"b = {b}")
# Out:
# a = 10
# b = 5

# %%
#Exercise 8
 
length = float(input("Enter length: "))
width = float(input("Enter width: ")) 
area = length * width
perimeter = 2 * (length + width)
print(f"Area: {area}")
print(f"Perimeter: {perimeter}")
# Out:
# Enter length:  20
# Enter width:  15
# Area: 300.0
# Perimeter: 70.0

# %%
#Exercise 9

print(7 // 2)
print(7 % 2)
print(2 ** 3)
print(10 > 5 and 3 > 5)
print(10 > 5 or 3 > 5)
print(not True)
print("5" + "5")
print(5 == 5.0)
# Out:
# 3
# 1
# 8
# False
# True
# False
# 55
# True

# %%
#Exercise 10

name = "Notebook"
price = 149
in_stock = True
status = "In Stock" if in_stock else "Out of Stock" 
print(f"{name} — ₹{price:.2f} ({status})")
# Out:
# Notebook — ₹149.00 (In Stock)

# %%
#Exercise 11

weight = float(input("Enter weight in kg: "))
height = float(input("Enter height in metres: "))
bmi = weight / (height ** 2)
print(f"BMI: {bmi:.1f}")
# Out:
# Enter weight in kg:  45
# Enter height in metres:  1.83
# BMI: 13.4

# %%
#Exercise 12

n = 15
 
div_by_3 = (n % 3 == 0)
div_by_5 = (n % 5 == 0)
div_by_both = div_by_3 and div_by_5
 
print(f"Divisible by 3: {div_by_3}")
print(f"Divisible by 5: {div_by_5}")
print(f"Divisible by both: {div_by_both}")
# Out:
# Divisible by 3: True
# Divisible by 5: True
# Divisible by both: True

# %%
#Exercise 13

amount = float(input("Enter amount in USD: "))
conversion_rate = float(input("Enter USD to INR conversion rate: "))
 
rupees = amount * conversion_rate 
print(f"${amount:,.2f} = ₹{rupees:,.2f}")
# Out:
# Enter amount in USD:  47
# Enter USD to INR conversion rate:  95
# $47.00 = ₹4,465.00

# %%
#Exeercise 14

score1 = float(input("Enter first score: "))
score2 = float(input("Enter second score: "))
score3 = float(input("Enter third score: ")) 
average = (score1 + score2 + score3) / 3 
has_passed = average >= 40 
print(f"Average: {average:.1f} | Passed: {has_passed}")
# Out:
# Enter first score:  8
# Enter second score:  9
# Enter third score:  10
# Average: 9.0 | Passed: False
