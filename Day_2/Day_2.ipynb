# %%
#Exercise-1 -- Name Tag Formatter  
first_name=input("Enter the first Name")
last_name=input("Enter the last Name")
print(f"Hello,{first_name.title()} {last_name.title()}!")
# Out:
# Enter the first Name visagan
# Enter the last Name rajakumar
# Hello,Visagan Rajakumar!

# %%
#Exercise 2---Coupon Code Slicer  
code = "PYTHON2026SALE"
print(code[:6])#first six chars
print(code[-4:])#last four chars
print(code[::-1])#whole word is reverse
# Out:
# PYTHON
# SALE
# ELAS6202NOHTYP

# %%
#Exercise 3---Palindrome Checker  
word="level"
is_palindrome=word==word[::-1]
print(is_palindrome)
# Out:
# True

# %%
#Exercise 4 ---Email Splitter  
email="visagan@gmail.com"
username,domain=email.split('@')
print(f"Username:{username},Domain: {domain}")
# Out:
# Username:visagan,Domain: gmail.com

# %%
#Exercise 5---Slug Normalizer  
title = "  My First   Python Project!!  "
title=title.strip()
title=title.replace("!!","")
title = title.lower()
print(title.replace(" ","_"))
# Out:
# my_first___python_project

# %%
#Exercise 6---Sentence Dashboard  
sentence="I am Visagan"
total_char=len(sentence)

word_cnt=len(sentence.split())

vowel_count = (
    sentence.count("a")
    + sentence.count("e")
    + sentence.count("i")
    + sentence.count("o")
    + sentence.count("u")
)

longer_than_30 = len(sentence) > 30
print(f"Total characters: {total_char}")

print(f"Word count: {word_cnt}")

print(f"Vowel count: {vowel_count}")

print(f"Longer than 30 characters: {longer_than_30}")
# Out:
# Total characters: 12
# Word count: 3
# Vowel count: 4
# Longer than 30 characters: False

# %%
#Exercise-7---Initials Generator  
full_name="Visagan Rajakumar"
names=full_name.split(" ")
intial=names[0][0]+names[1][0]
print(intial)
# Out:
# VR

# %%
# Exercise-8---Loading Bar
print("Full:", "=" * 20)
print("Partial:", "=" * 8 + "-" * 12)
# Out:
# Full: ====================
# Partial: ========------------

# %%
#Exercise-9---File Extension 
filename = "day2_notes.docx"
print(filename.endswith(".docx"))
# Out:
# True

# %%
#Exercise 10---Find and Replace Report  
text = "the quick brown fox"
print(text)
print(text.find("brown"))
print(text.replace("brown","red"))
# Out:
# the quick brown fox
# 10
# the quick red fox

# %%
#Exercise-11---Username Validator (Facts Only)  
username = "visagan_R12"
print(username.isalnum())
print(len(username))
print(len(username) >= 6)
# Out:
# False
# 11
# True

# %%
#Exercise 12---Title Case vs Capitalize
phrase = "the quick brown fox"
print(phrase.title())
print(phrase.capitalize())
# Out:
# The Quick Brown Fox
# The quick brown fox

# %%
#Exercise 13---Receipt Line Formatter  
item="Notebook"
price=149.0
print(f"{item:<15}|{price:>8.2f}")
# Out:
# Notebook       |  149.00

# %%
#PART-1------------------String Manipulation Script-------------------
sentence=input("Enter the sentence:")
print(len(sentence))
print(sentence.upper())
print(sentence.lower())
print(sentence[::-1])
print(len(sentence.split(" ")))
words=sentence.split(" ")
print(f"First word: {words[0]},Last word: {words[-1]}")
sentence=sentence.replace(" ","")
sentence=sentence.lower()
print("Old sentence is: ",sentence)
reverse=sentence[::-1]
print("rev sentence is: ",reverse)
print(sentence==reverse)
# Out:
# Enter the sentence: Never odd or even
# 17
# NEVER ODD OR EVEN
# never odd or even
# neve ro ddo reveN
# 4
# First word: Never,Last word: even
# Old sentence is:  neveroddoreven
# rev sentence is:  neveroddoreven
# True

# %%
#----------------------Part-2--—--Simple Calculator, Revisited
num1=float(input("Enter the first num:"))
num2=float(input("Enter the first num:"))
result=num1+num2
print("------------------------------------------")
print(f"{'Operation':<12}{'Op':^5}{'Result':>10}")
print("------------------------------------------")
print(f"{'Addition':<12}{'+':^5}{num1+num2:>10.2f}")
print(f"{'Subtraction':<12}{'-':^5}{num1-num2:>10.2f}")
print(f"{'Product':<12}{'*':^5}{num1*num2:>10.2f}")
print(f"{'Division':<12}{'/':^5}{num1/num2:>10.2f}")
print(f"{'Floor Div':<12}{'//':^5}{num1//num2:>10.2f}")
print(f"{'Exponent':<12}{'**':^5}{num1**num2:>10.2f}")
# Out:
# Enter the first num: 10
# Enter the first num: 3
# ------------------------------------------
# Operation    Op      Result
# ------------------------------------------
# Addition      +       13.00
# Subtraction   -        7.00
# Product       *       30.00
# Division      /        3.33
# Floor Div    //        3.00
# Exponent     **     1000.00
