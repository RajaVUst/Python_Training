# %%
#Exercise-1---Personal Info Card  
name="Aditi"
age=24
city="Chennai"
is_employed=True
print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print(f"Employeed: {is_employed}")
# Out:
# Name: Aditi
# Age: 24
# City: Chennai
# Employeed: True

# %%
#Exercise 2----Type Detective  
a = 10
b = 10.0
c = "10"
d = 10 == 10
e="True"
print(type(a))
print(type(b))
print(type(c))  
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>

# %%
#Exercise 3---Simple Calculator  
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
add=num1+num2
sub=num1-num2
product=num1*num2
div=num1/num2
print(f"Sum of two num is: {add}")
print(f"Sum of two num is: {sub}")
print(f"Sum of two num is: {product}")
print(f"Sum of two num is: {div}")
# Out:
# Enter first number:  20
# Enter second number:  5
# Sum of two num is: 25.0
# Sum of two num is: 15.0
# Sum of two num is: 100.0
# Sum of two num is: 4.0

# %%
#Exercise 4---Even or Odd (without if)  
n = 17
is_even = (n % 2 == 0)
print(f"{n} is even: {is_even}")
# Out:
# 17 is even: False

# %%
#  Exercise 5---Unit Converter  
temperature=float(input("Enter the temperature: "))
Fahrenheit=temperature*(9/5)+32

print(f"Temperature is: {temperature:.1f}")
print(f"Fahrenheit is: {Fahrenheit:.1f}")
# Out:
# Enter the temperature:  32
# Temperature is: 32.0
# Fahrenheit is: 89.6

# %%
#Exercise 6---Restaurant Bill Splitter  
bill = float(input("Enter total bill amount: "))
people = int(input("Enter number of people: "))
wants_tip = input("Do you want to add a 10% tip? (yes/no): ").lower() == "yes"

if wants_tip:
    bill = bill * 1.10

share = bill / people
print(f"Each person's share: ₹{share:.2f}")

# %%
#Exercise 7---Variable Swap  
a=5
b=10
temp=a
a=b
b=temp
print(f"a:{a},b:{b}")
c=10
d=20
c,d=d,c
print(f"c:{c},d:{d}")
# Out:
# a:10,b:5
# c:20,d:10

# %%
#Exercise 8---Rectangle Calculator  
length=float(input("Enter the length: "))
width=float(input("Enter the width: "))
area=length*width
perimeter=2*(length+width)
print(f"Area = {area}.Perimeter={perimeter}")
# Out:
# Enter the length:  20
# Enter the width:  4
# Area = 80.0.Perimeter=48.0

# %%
#Exercise 9 ---Predict the Output  
print(7 // 2)#3
print(7 % 2)#1
print(2 ** 3)#8
print(10 > 5 and 3 > 5)#false
print(10 > 5 or 3 > 5)#True
print(not True)#False
print("5" + "5")#55
print(5 == 5.0)#True
# Out:
# 3
# 1
# 8
# False
# True
# False
# 55
# True

# %%
# Exercise 10---Formatted Product Label  
pro_name = input("Enter the Product name: ")
price = float(input("Enter the Price: "))
in_stock = input("Enter True if it is in stock: ").lower() == "true"

print(f"{pro_name} — ${price:.2f} ({'In Stock' if in_stock else 'Out of Stock'})")
# Out:
# Enter the Product name:  Notebook
# Enter the Price:  149
# Enter True if it is in stock:  true
# Notebook — $149.00 (In Stock)

# %%
#  Exercise 11---BMI Calculator  
weight=float(input("Enter the weight"))#kg
height=float(input("Enter the height"))#meter
bmi=weight/(height**2)
print(f"Your BMI is: {bmi:.1f}")
# Out:
# Enter the weight 70
# Enter the height 1.75
# Your BMI is: 22.9

# %%
#Exercise 12---Divisibility Checker  
n = 15
div_by_3 = (n % 3 == 0)
div_by_5 = (n % 5 == 0)
div_by_both = div_by_3 and div_by_5
print(div_by_both)
# Out:
# True

# %%
#Exercise 13---Currency Converter  
amount=float(input("Enter an amount"))
rate=float(input("Enter conversion rate: "))
rupees = amount * rate
print(f"Indian Rupees: ₹{rupees:,.2f}")
# Out:
# Enter an amount 1234.50
# Enter conversion rate:  87.5
# Indian Rupees: ₹108,018.75

# %%
#  Exercise 14---Student Report Line  
score1 = float(input("Enter first test score: "))
score2 = float(input("Enter second test score: "))
score3 = float(input("Enter third test score: "))

average = (score1 + score2 + score3) / 3
has_passed = average >= 40

print(f"Average: {average:.1f} | Passed: {has_passed}")
# Out:
# Enter first test score:  98
# Enter second test score:  99
# Enter third test score:  100
# Average: 99.0 | Passed: True
