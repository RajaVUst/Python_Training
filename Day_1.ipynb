# %%
# Step 2: Declare four variables, one of each primitive type
name = "Deepshika"
age = 23
height_m = 1.65
has_coded_before = False

# %%
# Step 3: Print each variable's type to confirm Python's inference
print(type(name))
print(type(age))
print(type(height_m))
print(type(has_coded_before))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Step 4: Ask the user for their favourite number (input() always returns a str)
fav_str = input("Enter your favourite number: ")

# Step 5: Cast the string to an int, then print it doubled
fav_num = int(fav_str)
print(fav_num*2)
# Out:
# Enter your favourite number:  45
# 90

# %%
# Step 6: Combine at least three variables into one readable f-string
print(f"{name} is {age} years old and {height_m}m tall.")
# Out:
# Deepshika is 23 years old and 1.65m tall.

# %%
# Exercise 1 — Personal Info Card
name = "Deepshika"
age = 23
city = "Bangalore"
is_employed = True
 
print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print(f"Is Employed: {is_employed}")
# Out:
# Name: Deepshika
# Age: 23
# City: Bangalore
# Is Employed: True

# %%
# Exercise 2 — Type Detective
a = 10
b = 10.0
c = "10"
d = 10 == 10
e = "True"
 
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'str'>

# %%
# Exercise 3 — Simple Calculator
num1=float(input("Enter first number: "))
num2=float(input("Enter second number: "))
 
print(f"Addition: {num1 + num2}")
print(f"Subtraction: {num1 - num2}")
print(f"Multiplication: {num1 * num2}")
print(f"Division: {num1 / num2}")
# Out:
# Enter first number:  5
# Enter second number:  6
# Addition: 11.0
# Subtraction: -1.0
# Multiplication: 30.0
# Division: 0.8333333333333334

# %%
# Exercise 4 — Even or Odd
n=13
is_even=(n%2==0)
print(f"{n} is even: {is_even}")
# Out:
# 13 is even: False

# %%
# Exercise 5 — Unit Converter
cels=float(input("Enter the temperature value in Celsius: "))

fahr=cels*9/5+32

print(f"Temperature in Celsius is {cels} and in Fahrenheit is {fahr}")
# Out:
# Enter the temperature value in Celsius:  4
# Temperature in Celsius is 4.0 and in Fahrenheit is 39.2

# %%
# Exercise 6 — Restaurant Bill Splitter
total_bill = float(input("Enter the total bill amount: "))

num_people = int(input("Enter the number of people: "))
 
wants_tip = input("Add a 10% tip? (yes/no): ").strip().lower() == "yes"
 
if wants_tip:

    total_bill *= 1.10
 
share_per_person = total_bill / num_people
 
print(f"Each person's share: ${share_per_person:.2f}")
# Out:
# Enter the total bill amount:  45
# Enter the number of people:  4
# Add a 10% tip? (yes/no):  yes
# Each person's share: $12.38

# %%
# Exercise 7 — Variable Swap
a = 5

b = 10
 
temp = a

a = b

b = temp
 
print(f"a = {a}")

print(f"b = {b}")
# Out:
# a = 10
# b = 5

# %%
a, b = b, a
 
print(f"a = {a}")

print(f"b = {b}")
# Out:
# a = 5
# b = 10

# %%
# Exercise 8 — Rectangle Calculator
length = float(input("Enter the rectangle's length: "))

width = float(input("Enter the rectangle's width: "))
 
area = length * width

perimeter = 2 * (length + width)
 
print(f"Area: {area}")

print(f"Perimeter: {perimeter}")
# Out:
# Enter the rectangle's length:  6
# Enter the rectangle's width:  4
# Area: 24.0
# Perimeter: 20.0

# %%
# Exercise 9 — Predict the Output
print(7 // 2)

print(7 % 2)

print(2 ** 3)

print(10 > 5 and 3 > 5)

print(10 > 5 or 3 > 5)

print(not True)

print("5" + "5")

print(5 == 5.0)
# Out:
# 3
# 1
# 8
# False
# True
# False
# 55
# True

# %%
# Exercise 10 — Formatted Product Label
name = "Notebook"
price = 149.0
in_stock = True
 
print(f"{name} — ₹{price:.2f} ({'In Stock' if in_stock else 'Out of Stock'})")
# Out:
# Notebook — ₹149.00 (In Stock)

# %%
# Exercise 11 — BMI Calculator
weight = float(input("Enter your weight in kilograms: "))
height = float(input("Enter your height in metres: "))
 
bmi = weight / (height ** 2)
 
print(f"Your BMI is: {bmi:.1f}")
# Out:
# Enter your weight in kilograms:  32
# Enter your height in metres:  4
# Your BMI is: 2.0

# %%
# Exercise 12 — Divisibility Checker
n=15
div_by_3=(n%3==0)
div_by_5=(n%5==0)
div_by_both=div_by_3 and div_by_5
 
print(f"Divisible by 3: {div_by_3}")
print(f"Divisible by 5: {div_by_5}")
print(f"Divisible by both: {div_by_both}")
# Out:
# Divisible by 3: True
# Divisible by 5: True
# Divisible by both: True

# %%
# Exercise 13 — Currency Converter
usd_amount = float(input("Enter the amount in US Dollars: "))
conversion_rate = float(input("Enter the USD to INR conversion rate: "))
 
inr_amount = usd_amount * conversion_rate
 
print(f"${usd_amount:,.2f} = ₹{inr_amount:,.2f}")
# Out:
# Enter the amount in US Dollars:  20
# Enter the USD to INR conversion rate:  10
# $20.00 = ₹200.00

# %%
# Exercise 14 — Student Report Line
score1 = float(input("Enter the first test score: "))

score2 = float(input("Enter the second test score: "))

score3 = float(input("Enter the third test score: "))
 
average = (score1 + score2 + score3) / 3

has_passed = average >= 40
 
print(f"Average: {average:.1f} | Passed: {has_passed}")
# Out:
# Enter the first test score:  60
# Enter the second test score:  50
# Enter the third test score:  40
# Average: 50.0 | Passed: True
