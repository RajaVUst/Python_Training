# %%
#exercise 1
items = ["pen", "notebook", "pen", "eraser", "notebook", "pen", "stapler"]
lst = []
tp = ()
st = set()
dc = {}
lst = items.copy()
print("List : ",lst)
tp = tuple(items[:3])
print("Tuple : ",tp)
for i in items:
    st.add(i)
print("set : ",st)
for i in items:
    if i in dc:
        dc[i] += 1
    else:
        dc[i] = 1
print("dictionary : ",dc)
# Out:
# List :  ['pen', 'notebook', 'pen', 'eraser', 'notebook', 'pen', 'stapler']
# Tuple :  ('pen', 'notebook', 'pen')
# set :  {'pen', 'eraser', 'stapler', 'notebook'}
# dictionary :  {'pen': 3, 'notebook': 2, 'eraser': 1, 'stapler': 1}

# %%
#exercise 2
squares = [n*n for n in range(1,21) if n%2 == 0]
word_lengths = {len(word) for word in["python", "java", "c", "kotlin"]}
unique_vowels = set(ch for ch in "the quick brown fox jumps over the lazy dog" if ch in "aeiou")
print(squares)
print(word_lengths)
print(unique_vowels)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400]
# {1, 4, 6}
# {'i', 'o', 'u', 'a', 'e'}

# %%
##exercise 3

sentences = ["the sky is blue", "python is fun", "list comprehensions are handy"]
long_words = [word for sentence in sentences for word in sentence.split() if len(word) > 2]
unique_words = {word.lower() for sentence in sentences for word in sentence.split()}
print(long_words)
print(unique_words)
# Out:
# ['the', 'sky', 'blue', 'python', 'fun', 'list', 'comprehensions', 'are', 'handy']
# {'sky', 'list', 'python', 'the', 'is', 'are', 'blue', 'handy', 'comprehensions', 'fun'}

# %%
students = {
    "alice": [88, 92, 79],
    "bob": [65, 70, 68],
    "carol": [95, 91, 89],
    "dave": []
}
averages = {
    name: sum(grades) / len(grades) if grades else 0
    for name, grades in students.items()
}

print("Averages:", averages)
above_80 = {
    name for name, grades in students.items()
    if grades and all(grade > 80 for grade in grades)
}

print("Every grade above 80:", above_80)
sorted_students = sorted(
    averages.items(),
    key=lambda item: item[1],
    reverse=True
)
print("Sorted:", sorted_students)
# Out:
# Averages: {'alice': 86.33333333333333, 'bob': 67.66666666666667, 'carol': 91.66666666666667, 'dave': 0}
# Every grade above 80: {'carol'}
# Sorted: [('carol', 91.66666666666667), ('alice', 86.33333333333333), ('bob', 67.66666666666667), ('dave', 0)]

# %%
team_a = {"figma", "jira", "slack", "github"}
team_b = {"jira", "slack", "notion", "vscode"}
common = team_a & team_b
only_a = team_a - team_b
combined = team_a | team_b
symmetric = team_a ^ team_b
print("Common:", common)
print("Only Team A:", only_a)
print("Combined:", combined)
print("Symmetric difference:", symmetric)
# Out:
# Common: {'jira', 'slack'}
# Only Team A: {'figma', 'github'}
# Combined: {'vscode', 'figma', 'slack', 'github', 'notion', 'jira'}
# Symmetric difference: {'vscode', 'figma', 'github', 'notion'}

# %%
def add_item(item, basket=[]):
    basket.append(item)
    return basket

print(add_item("apple"))
print(add_item("banana"))
# Out:
# ['apple']
# ['apple', 'banana']

# %%
def add_item(item, basket=None):
    if basket is None:
        basket = []

    basket.append(item)
    return basket


print(add_item("apple"))
print(add_item("banana"))
# Out:
# ['apple']
# ['banana']

# %%
def add_student(name, students):
    students.append(name)


class_students = ["Alice", "Bob"]

add_student("Carol", class_students)

print(class_students)
# Out:
# ['Alice', 'Bob', 'Carol']

# %%
log_lines = [
    "Application started\n",
    "User logged in\n",
    "File uploaded\n",
    "Report generated\n",
    "Application stopped\n"
]
with open("log.txt", "w") as file:
    file.writelines(log_lines)
with open("log.txt", "r") as file:
    for number, line in enumerate(file, start=1):
        print(number, line.strip())
# Out:
# 1 Application started
# 2 User logged in
# 3 File uploaded
# 4 Report generated
# 5 Application stopped

# %%
import csv

employees = [
    ["Alice", "Engineering", 80000],
    ["Bob", "Sales", 60000],
    ["Carol", "Engineering", 90000],
    ["David", "HR", 55000],
    ["Eve", "Sales", 65000]
]
with open("employees.csv", "w", newline="") as file:
    writer = csv.writer(file)

    writer.writerow(["name", "department", "salary"])
    writer.writerows(employees)

employee_records = []

with open("employees.csv", "r", newline="") as file:
    reader = csv.DictReader(file)

    for employee in reader:
        print(employee)
        employee_records.append(employee)
department_totals = {}

for employee in employee_records:
    department = employee["department"]
    salary = float(employee["salary"])

    department_totals[department] = (
        department_totals.get(department, 0) + salary
    )

print("Department totals:", department_totals)

for employee in employee_records:
    if employee["department"] == "Engineering":
        salary = float(employee["salary"])
        employee["salary"] = f"{salary * 1.10:.2f}"
with open("employees_updated.csv", "w", newline="") as file:
    fieldnames = ["name", "department", "salary"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(employee_records)
# Out:
# {'name': 'Alice', 'department': 'Engineering', 'salary': '80000'}
# {'name': 'Bob', 'department': 'Sales', 'salary': '60000'}
# {'name': 'Carol', 'department': 'Engineering', 'salary': '90000'}
# {'name': 'David', 'department': 'HR', 'salary': '55000'}
# {'name': 'Eve', 'department': 'Sales', 'salary': '65000'}
# Department totals: {'Engineering': 170000.0, 'Sales': 125000.0, 'HR': 55000.0}

# %%
import json

config = {
    "app_name": "InventoryApp",
    "version": 1.2,
    "features": ["export", "search", "notifications"],
    "limits": {
        "max_users": 100,
        "max_items": 5000
    }
}
with open("config.json", "w") as file:
    json.dump(config, file, indent=2)
with open("config.json", "r") as file:
    config = json.load(file)

print(config["limits"]["max_users"])
config["features"].append("dark_mode")
with open("config.json", "w") as file:
    json.dump(config, file, indent=2)
# Out:
# 100

# %%
def safe_divide(a, b):
    try:
        return a / b

    except ZeroDivisionError:
        print("Warning: Cannot divide by zero.")
        return None

    except TypeError:
        print("Warning: Both values must support division.")
        return None

    finally:
        print("Operation attempted")


print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide("10", 2))
# Out:
# Operation attempted
# 5.0
# Warning: Cannot divide by zero.
# Operation attempted
# None
# Warning: Both values must support division.
# Operation attempted
# None

# %%
import csv
import json


def convert_orders():
    totals_by_customer = {}
    statuses = set()

    try:
        with open("orders.csv", "r", newline="") as file:
            reader = csv.DictReader(file)

            for row_number, row in enumerate(reader, start=2):
                customer = row["customer"]
                amount_text = row["amount"]

                try:
                    amount = float(amount_text)

                except (ValueError, TypeError):
                    print(
                        f"Warning: Invalid amount on row "
                        f"{row_number} for customer {customer}. Skipping."
                    )
                    continue
                totals_by_customer[customer] = (
                    totals_by_customer.get(customer, 0) + amount
                )
                statuses.add(row["status"])
        summary = {
            "totals_by_customer": totals_by_customer,
            "statuses": sorted(statuses)
        }
        with open("orders_summary.json", "w") as file:
            json.dump(summary, file, indent=2)

        print("Conversion successful.")
        print(summary)

    except FileNotFoundError:
        print("Error: orders.csv was not found.")

    except Exception as error:
        print(f"Unexpected error: {error}")

    finally:
        print("Conversion attempt finished")


convert_orders()
# Out:
# Conversion successful.
# {'totals_by_customer': {}, 'statuses': []}
# Conversion attempt finished
