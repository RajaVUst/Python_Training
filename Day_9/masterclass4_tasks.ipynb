# %%
class TrainingRun:
    run_count = 0

    def __init__(self, model_name, learning_rate):
        self.model_name = model_name
        self.learning_rate = learning_rate
        self.status = "not started"

        TrainingRun.run_count += 1

    def start(self):
        self.status = "running"
        print(f"Training started for {self.model_name}")

    def summary(self):
        return (
            f"Model: {self.model_name}, "
            f"Learning rate: {self.learning_rate}, "
            f"Status: {self.status}"
        )

    @classmethod
    def from_config(cls, config_dict):
        return cls(
            model_name=config_dict["model_name"],
            learning_rate=config_dict["learning_rate"]
        )

run1 = TrainingRun("ResNet50", 0.001)
run2 = TrainingRun("BERT", 0.0001)
run3 = TrainingRun("GPT", 0.00005)

print(TrainingRun.run_count)  # 3

run1.start()
print(run1.summary())

config = {
    "model_name": "Llama",
    "learning_rate": 0.0002
}

run4 = TrainingRun.from_config(config)
print(run4.summary())
# Out:
# 3
# Training started for ResNet50
# Model: ResNet50, Learning rate: 0.001, Status: running
# Model: Llama, Learning rate: 0.0002, Status: not started

# %%
class TrainingRun:
    run_count = 0

    def __init__(self, model_name, learning_rate):
        self.model_name = model_name
        self.learning_rate = learning_rate
        self._status = "pending"
        self.__api_key = "fake-training-token-123"

        TrainingRun.run_count += 1

    @property
    def status(self):
        return self._status

    @status.setter
    def status(self, value):
        if value not in ("pending", "running", "done"):
            raise ValueError(
                "Status must be 'pending', 'running', or 'done'"
            )

        self._status = value

    def start(self):
        self.status = "running"
        print(f"Training started for {self.model_name}")

    def finish(self):
        self.status = "done"
        print(f"Training finished for {self.model_name}")

    def summary(self):
        return (
            f"Model: {self.model_name}, "
            f"Learning rate: {self.learning_rate}, "
            f"Status: {self.status}"
        )

run = TrainingRun("ResNet50", 0.001)

print(run.status)

run.status = "running"
print(run.status)

run.status = "done"
print(run.status)

print(run._TrainingRun__api_key)
# Out:
# pending
# running
# done
# fake-training-token-123

# %%
class TrainingRun:
    run_count = 0

    def __init__(self, model_name, learning_rate):
        self.model_name = model_name
        self.learning_rate = learning_rate
        self._status = "pending"
        self.__api_key = "fake-training-token-123"

        TrainingRun.run_count += 1

    @property
    def status(self):
        return self._status

    @status.setter
    def status(self, value):
        if value not in ("pending", "running", "done"):
            raise ValueError(
                "Status must be 'pending', 'running', or 'done'"
            )

        self._status = value

    def start(self):
        self.status = "running"
        print(f"Training started for {self.model_name}")

    def summary(self):
        return (
            f"Model: {self.model_name}, "
            f"Learning rate: {self.learning_rate}, "
            f"Status: {self.status}"
        )
class LRSchedulerRun(TrainingRun):

    def __init__(self, model_name, learning_rate, schedule):
        super().__init__(model_name, learning_rate)

        self.schedule = schedule

    def summary(self):
        parent_summary = super().summary()

        current_lr = self.schedule[0]

        return (
            f"{parent_summary}, "
            f"Current scheduled learning rate: {current_lr}, "
            f"Schedule: {self.schedule}"
        )
run1 = TrainingRun("ResNet50", 0.001)
run2 = LRSchedulerRun(
    "BERT",
    0.001,
    [0.001, 0.0005, 0.0001]
)

print(run2.summary())

print(TrainingRun.run_count)
# Out:
# Model: BERT, Learning rate: 0.001, Status: pending, Current scheduled learning rate: 0.001, Schedule: [0.001, 0.0005, 0.0001]
# 2

# %%
class TrainingRun:
    run_count = 0

    def __init__(self, model_name, learning_rate):
        self.model_name = model_name
        self.learning_rate = learning_rate
        self._status = "pending"

        TrainingRun.run_count += 1

    @property
    def status(self):
        return self._status

    @status.setter
    def status(self, value):
        if value not in ("pending", "running", "done"):
            raise ValueError(
                "Status must be 'pending', 'running', or 'done'"
            )

        self._status = value

    def summary(self):
        return (
            f"Model: {self.model_name}, "
            f"Learning rate: {self.learning_rate}, "
            f"Status: {self.status}"
        )


class LRSchedulerRun(TrainingRun):

    def __init__(self, model_name, learning_rate, schedule):
        super().__init__(model_name, learning_rate)
        self.schedule = schedule

    def summary(self):
        parent_summary = super().summary()

        current_lr = self.schedule[0]

        return (
            f"{parent_summary}, "
            f"Current scheduled LR: {current_lr}, "
            f"Schedule: {self.schedule}"
        )


class EarlyStoppingRun(TrainingRun):

    def __init__(self, model_name, learning_rate, patience):
        super().__init__(model_name, learning_rate)
        self.patience = patience

    def summary(self):
        parent_summary = super().summary()

        return (
            f"{parent_summary}, "
            f"Early stopping patience: {self.patience} epochs"
        )


def print_all_summaries(runs):
    for run in runs:
        print(run.summary())


runs = [
    TrainingRun("ResNet", 0.001),
    LRSchedulerRun("BERT", 0.0005, [0.0005, 0.0001, 0.00001]),
    EarlyStoppingRun("GPT", 0.0001, 5)
]

print_all_summaries(runs)
# Out:
# Model: ResNet, Learning rate: 0.001, Status: pending
# Model: BERT, Learning rate: 0.0005, Status: pending, Current scheduled LR: 0.0005, Schedule: [0.0005, 0.0001, 1e-05]
# Model: GPT, Learning rate: 0.0001, Status: pending, Early stopping patience: 5 epochs

# %%
class Cleaner:
    def process(self, data):
        return data.strip()


class Tokenizer:
    def process(self, data):
        return data.split()


class Normalizer:
    def process(self, data):
        return [word.lower() for word in data]


def run_pipeline(steps, data):
    for step in steps:
        data = step.process(data)

    return data


# Create pipeline steps
steps = [
    Cleaner(),
    Tokenizer(),
    Normalizer()
]

# Run the pipeline
data = "  Hello WORLD Python  "

result = run_pipeline(steps, data)

print("Duck Typing Result:")
print(result)


# ============================================================
# TASK 5 - ABSTRACT BASE CLASS (ABC)
# ============================================================

from abc import ABC, abstractmethod


class Step(ABC):

    @abstractmethod
    def process(self, data):
        pass


class CleanerABC(Step):
    def process(self, data):
        return data.strip()


class TokenizerABC(Step):
    def process(self, data):
        return data.split()


class NormalizerABC(Step):
    def process(self, data):
        return [word.lower() for word in data]


def run_pipeline_abc(steps, data):
    for step in steps:
        data = step.process(data)

    return data

abc_steps = [
    CleanerABC(),
    TokenizerABC(),
    NormalizerABC()
]

data = "  Hello WORLD Python  "

result = run_pipeline_abc(abc_steps, data)

print("\nABC Result:")
print(result)

try:
    step = Step()
except TypeError as e:
    print("\nTrying Step():")
    print("TypeError:", e)
# Out:
# Duck Typing Result:
# ['hello', 'world', 'python']
#
# ABC Result:
# ['hello', 'world', 'python']
#
# Trying Step():
# TypeError: Can't instantiate abstract class Step without an implementation for abstract method 'process'

# %%
# TASK 6 - DUNDER METHODS
class TrainingRun:

    def __init__(self, model_name, learning_rate):
        self.model_name = model_name
        self.learning_rate = learning_rate


    def __str__(self):
        return (
            f"TrainingRun(model='{self.model_name}', "
            f"lr={self.learning_rate})"
        )

    def __eq__(self, other):

        if not isinstance(other, TrainingRun):
            return NotImplemented

        return (
            self.model_name == other.model_name
            and self.learning_rate == other.learning_rate
        )

    def __repr__(self):
        return (
            f"TrainingRun("
            f"model_name={self.model_name!r}, "
            f"learning_rate={self.learning_rate!r})"
        )

run1 = TrainingRun("gpt-mini", 0.01)

run2 = TrainingRun("gpt-mini", 0.01)

run3 = TrainingRun("BERT", 0.001)

print("Testing __str__:")
print(run1)
print("\nTesting __eq__:")

print(run1 == run2)   # True
print(run1 == run3)   # False
print("\nTesting __repr__:")

print(repr(run1))
# Out:
# Testing __str__:
# TrainingRun(model='gpt-mini', lr=0.01)
#
# Testing __eq__:
# True
# False
#
# Testing __repr__:
# TrainingRun(model_name='gpt-mini', learning_rate=0.01)
