# %% [markdown]
# # Part A — Lists

# %%
#Exercise 1: Shopping List Manager
cart = ['milk', 'eggs', 'bread']
cart.append('rice')
cart.append('fruits')
cart.remove('milk')
print(sorted(cart))
# Out:
# ['bread', 'eggs', 'fruits', 'rice']

# %%
#Exercise 2: Rotate the Queue
queue = ["Amit", "Reni", "Tara", "Sam"]
print(queue)
queue.append(queue.pop(0))
print(queue)
# Out:
# ['Amit', 'Reni', 'Tara', 'Sam']
# ['Reni', 'Tara', 'Sam', 'Amit']

# %%
#Exercise 3: Running Total With Slicing
readings = [12, 15, 9, 22, 30, 4, 18]
print(readings[0:3])
print(readings[:-3:-1])
print(readings[0::2])
# Out:
# [12, 15, 9]
# [18, 4]
# [12, 9, 30, 18]

# %%
#Exercise 4: Copy vs. Reference
original = [1, 2, 3]
alias = original
safe_copy = original.copy()
alias.append(100)
safe_copy.append(200)

print(original)
print(alias)
print(safe_copy)

# original changes with alias because both refer to the same list but safe_copy is a separate copy.
# Out:
# [1, 2, 3, 100]
# [1, 2, 3, 100]
# [1, 2, 3, 200]

# %% [markdown]
# # Part B — Tuples

# %%
#Exercise 5: Coordinates
location = (12.97, 77.59)
location[0] = 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 #Exercise 5: Coordinates
#       2 location = (12.97, 77.59)
# ----> 3 location[0] = 12
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Exercise 6: Unpacking a Tuple
record = ("Reni", 91, "Cohort 2")
name, score, cohort = record
print(f"{name} scored {score} and belongs to {cohort}")
# Out:
# Reni scored 91 and belongs to Cohort 2

# %%
#Exercise 7: Multiple Return Values
def stats(numbers):
    return min(numbers), max(numbers), (sum(numbers))/len(numbers)
    
numbers = stats([4, 9, 1, 7, 15])

low, high, avg = stats(numbers)

print(f"Minimum: {low}")
print(f"Maximum: {high}")
print(f"Average: {avg}")
# Out:
# Minimum: 1
# Maximum: 15
# Average: 7.733333333333333

# %% [markdown]
# # Part C — Sets

# %%
#Exercise 8: De-duplicating Attendance
attendance = ["amit", "reni", "amit", "tara", "reni", "sam"]
attendance = set(attendance)
print(len(attendance))
# Out:
# 4

# %%
#Exercise 9: Common Interests
cohort_a = {"python", "sql", "excel"}
cohort_b = {"python", "tableau", "excel"}

print("Common:", cohort_a & cohort_b)
print("Unique to cohort_a:", cohort_a - cohort_b)
print("All skills:", cohort_a | cohort_b)
# Out:
# Common: {'excel', 'python'}
# Unique to cohort_a: {'sql'}
# All skills: {'tableau', 'python', 'excel', 'sql'}

# %%
#Exercise 10: Fast Membership Check
seen = set(range(1000))
if 999 in seen:
    print("999 is present")
else:
    print("999 is not present")
# Out:
# 999 is present

# %% [markdown]
# # Part D — Dictionaries & Nested Structures

# %%
#Exercise 11: Contact Card
contact = {
    "name": "Ardra",
    "email": "ardra@gmail.com",
    "phone": "9876543210"
}

# Print each value by key
print(contact["name"])
print(contact["email"])
print(contact["phone"])

# Add a new key
contact["city"] = "Trivandrum"

# Update the phone number
contact["phone"] = "9876501234"

# Remove the email key
contact.pop("email")

print(contact)
# Out:
# Ardra
# ardra@gmail.com
# 9876543210
# {'name': 'Ardra', 'phone': '9876501234', 'city': 'Trivandrum'}

# %%
#Exercise 12: Word Frequency Counter
text = "the quick brown fox jumps over the lazy dog the fox runs"
words = text.split()
word_counts = {}

for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

print(word_counts)
# Out:
# {'the': 3, 'quick': 1, 'brown': 1, 'fox': 2, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1, 'runs': 1}

# %%
#Exercise 13: Class Roster (Nested Structure)
roster = [
    {"name": "Annie", "scores": [85, 90, 92]},
    {"name": "Minnie", "scores": [78, 88, 84]},
    {"name": "Winnie", "scores": [95, 91, 89]}
]

for i in roster:
    average = sum(i["scores"]) / len(i["scores"])
    print(f"{i['name']}: {average:.1f}")
# Out:
# Annie: 89.0
# Minnie: 83.3
# Winnie: 91.7

# %%
#Exercise 14: Lookup Table
grade_lookup = {"A":90, "B":80, "C":70, "D":60, "F":0}

score = 84

for grade, threshold in grade_lookup.items():
    if score >= threshold:
        print(f"Grade: {grade}")
        break
# Out:
# Grade: B

# %% [markdown]
# # Part E — Comprehensions

# %%
#Exercise 15: Squares and Cubes
cubes = [n**3 for n in range(1, 11)]
even_cubes = [n**3 for n in range(1, 11) if n % 2 == 0]

print("Cubes:", cubes)
print("Even cubes:", even_cubes)
# Out:
# Cubes: [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
# Even cubes: [8, 64, 216, 512, 1000]

# %%
#Exercise 16: Label the Temperatures
temps = [15, 22, 31, 8, 27, 19]
labels = ["hot" if t >= 25 else ("mild" if t >= 15 else "cold") for t in temps]

print(labels)
# Out:
# ['mild', 'mild', 'hot', 'cold', 'hot', 'mild']

# %%
#Exercise 17: Dictionary From Two Lists
names = ["Amit", "Reni", "Tara"]
scores = [78, 91, 65]

student_scores = {
    name: score
    for name, score in zip(names, scores)
}

print(student_scores)
# Out:
# {'Amit': 78, 'Reni': 91, 'Tara': 65}

# %%
#Exercise 18: Filtering With a Dict Comprehension
names = ["Amit", "Reni", "Tara"]
scores = [78, 91, 65]

scores_dict = {name: score for name, score in zip(names, scores)}

filtered_scores = {
    name: score
    for name, score in scores_dict.items()
    if score >= 70
}

print(filtered_scores)
# Out:
# {'Amit': 78, 'Reni': 91}

# %% [markdown]
# # Part F — Cumulative Challenges (Days 1-5)

# %%
#Exercise 19: Vowel Counter by Word
def vowel_counts(sentence):
    words = sentence.lower().split()
    counts = {}
    for word in words:
        count = 0
        for char in word:
            if char in "aeiou":
                count += 1
        counts[word] = count
    return counts

sentence = "The Quick Brown Fox Jumps"
result = vowel_counts(sentence)

print(result)
# Out:
# {'the': 1, 'quick': 2, 'brown': 1, 'fox': 1, 'jumps': 1}

# %%
# Exercise 20: Grade Book Summary

def grade_summary(roster):
    result = []

    for student in roster:
        name = student["name"]
        scores = student["scores"]
        average = sum(scores) / len(scores)

        if average >= 90:
            grade = "A"
        elif average >= 80:
            grade = "B"
        elif average >= 70:
            grade = "C"
        elif average >= 60:
            grade = "D"
        else:
            grade = "F"

        result.append({
            "name": name,
            "average": average,
            "grade": grade
        })
    return result

roster = [
    {"name": "Amit", "scores": [85, 90, 88]},
    {"name": "Reni", "scores": [95, 92, 96]},
    {"name": "Tara", "scores": [65, 70, 68]}
]

result = grade_summary(roster)
print(result)
# Out:
# [{'name': 'Amit', 'average': 87.66666666666667, 'grade': 'B'}, {'name': 'Reni', 'average': 94.33333333333333, 'grade': 'A'}, {'name': 'Tara', 'average': 67.66666666666667, 'grade': 'D'}]

# %%
# Exercise 21: Unique Word Finder

def unique_words(text):
    words = text.lower().split()
    unique = set(words)
    return sorted(unique)

text = "The cat and the dog and the cat"
result = unique_words(text)

print(result)
# Out:
# ['and', 'cat', 'dog', 'the']

# %%
# Exercise 22: FizzBuzz, Structured

def fizzbuzz_map(n):
    result = {}

    for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
            result[i] = "FizzBuzz"
        elif i % 3 == 0:
            result[i] = "Fizz"
        elif i % 5 == 0:
            result[i] = "Buzz"
        else:
            result[i] = str(i)

    return result

result = fizzbuzz_map(20)
print(result)
# Out:
# {1: '1', 2: '2', 3: 'Fizz', 4: '4', 5: 'Buzz', 6: 'Fizz', 7: '7', 8: '8', 9: 'Fizz', 10: 'Buzz', 11: '11', 12: 'Fizz', 13: '13', 14: '14', 15: 'FizzBuzz', 16: '16', 17: '17', 18: 'Fizz', 19: '19', 20: 'Buzz'}

# %%
# Exercise 23: Password Strength Report (Capstone)

def password_report(passwords):
    result = {
        "weak": [],
        "medium": [],
        "strong": []
    }

    for pw in passwords:
        has_digit = any(ch.isdigit() for ch in pw)

        if len(pw) >= 10 and has_digit:
            result["strong"].append(pw)
        elif len(pw) >= 6:
            result["medium"].append(pw)
        else:
            result["weak"].append(pw)

    return result

passwords = [
    "abc",
    "hello1",
    "python",
    "password123",
    "StrongPass9",
    "hello"
]

result = password_report(passwords)
print(result)
# Out:
# {'weak': ['abc', 'hello'], 'medium': ['hello1', 'python'], 'strong': ['password123', 'StrongPass9']}
